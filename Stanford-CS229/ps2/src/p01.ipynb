# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataA = pd.read_csv("../data/ds1_a.csv")

# %%
dataA.head()
# Out:
#      y        x0        x1
# 0 -1.0  0.601266  0.165091
# 1  1.0  0.871725  0.527361
# 2 -1.0  0.372548  0.446609
# 3 -1.0  0.013577  0.051358
# 4  1.0  0.583032  0.710619

# %%
dataB = pd.read_csv("../data/ds1_b.csv")

# %%
plt.plot(dataA.x0.loc[dataA.y == -1.0],dataA.x1.loc[dataA.y == -1.0],'bo',label = "y = -1")
plt.plot(dataA.x0.loc[dataA.y == 1.0],dataA.x1.loc[dataA.y == 1.0],'ro',label = "y = 1")
plt.xlabel("x0")
plt.ylabel("x1")
